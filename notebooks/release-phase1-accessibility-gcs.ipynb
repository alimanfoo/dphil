# %%
# download accessibility HDF5 from FTP
# !mkdir -pv ../data/external
# !wget --no-clobber ftp://ngs.sanger.ac.uk/production/ag1000g/phase1/AR3/accessibility/accessibility.h5 -O ../data/external/accessibility.h5
# Out:
# File ‘../data/external/accessibility.h5’ already there; not retrieving.

# %%
import zarr

dest = zarr.open('../data/external/accessibility.zarr', mode='w')

import h5py

source = h5py.File('../data/external/accessibility.h5', mode='r')

# %%
print(zarr.tree(source))
# Out:
# /
#  ├── 2L
#  │   ├── coverage (49364325,) int64
#  │   ├── coverage_mq0 (49364325,) int64
#  │   ├── filter_dust (49364325,) bool
#  │   ├── filter_high_coverage (49364325,) bool
#  │   ├── filter_high_mq0 (49364325,) bool
#  │   ├── filter_low_coverage (49364325,) bool
#  │   ├── filter_low_mq (49364325,) bool
#  │   ├── filter_n (49364325,) bool
#  │   ├── filter_no_coverage (49364325,) bool
#  │   ├── high_coverage (49364325,) int32
#  │   ├── high_mq0 (49364325,) int32
#  │   ├── is_accessible (49364325,) bool
#  │   ├── low_coverage (49364325,) int32
#  │   ├── low_mq (49364325,) int32
#  │   ├── low_pairing (49364325,) int32
#  │   ├── no_coverage (49364325,) int32
#  │   ├── pos (49364325,) int64
#  │   ├── ref (49364325,) |S1
#  │   ├── ref_masked (49364325,) bool
#  │   ├── ref_n (49364325,) bool
#  │   ├── repeat_dust (49364325,) bool
#  │   ├── repeat_repeatmask (49364325,) bool
#  │   └── repeat_trf (49364325,) bool
#  ├── 2R
#  │   ├── coverage (61545105,) int64
#  │   ├── coverage_mq0 (61545105,) int64
#  │   ├── filter_dust (61545105,) bool
#  │   ├── filter_high_coverage (61545105,) bool
#  │   ├── filter_high_mq0 (61545105,) bool
#  │   ├── filter_low_coverage (61545105,) bool
#  │   ├── filter_low_mq (61545105,) bool
#  │   ├── filter_n (61545105,) bool
#  │   ├── filter_no_coverage (61545105,) bool
#  │   ├── high_coverage (61545105,) int32
#  │   ├── high_mq0 (61545105,) int32
#  │   ├── is_accessible (61545105,) bool
#  │   ├── low_coverage (61545105,) int32
#  │   ├── low_mq (61545105,) int32
#  │   ├── low_pairing (61545105,) int32
#  │   ├── no_coverage (61545105,) int32
#  │   ├── pos (61545105,) int64
#  │   ├── ref (61545105,) |S1
#  │   ├── ref_masked (61545105,) bool
#  │   ├── ref_n (61545105,) bool
#  │   ├── repeat_dust (61545105,) bool
#  │   ├── repeat_repeatmask (61545105,) bool
#  │   └── repeat_trf (61545105,) bool
#  ├── 3L
#  │   ├── coverage (41963435,) int64
#  │   ├── coverage_mq0 (41963435,) int64
#  │   ├── filter_dust (41963435,) bool
#  │   ├── filter_high_coverage (41963435,) bool
#  │   ├── filter_high_mq0 (41963435,) bool
#  │   ├── filter_low_coverage (41963435,) bool
#  │   ├── filter_low_mq (41963435,) bool
#  │   ├── filter_n (41963435,) bool
#  │   ├── filter_no_coverage (41963435,) bool
#  │   ├── high_coverage (41963435,) int32
#  │   ├── high_mq0 (41963435,) int32
#  │   ├── is_accessible (41963435,) bool
#  │   ├── low_coverage (41963435,) int32
#  │   ├── low_mq (41963435,) int32
#  │   ├── low_pairing (41963435,) int32
#  │   ├── no_coverage (41963435,) int32
#  │   ├── pos (41963435,) int64
#  │   ├── ref (41963435,) |S1
#  │   ├── ref_masked (41963435,) bool
#  │   ├── ref_n (41963435,) bool
#  │   ├── repeat_dust (41963435,) bool
#  │   ├── repeat_repeatmask (41963435,) bool
#  │   └── repeat_trf (41963435,) bool
#  ├── 3R
#  │   ├── coverage (53200684,) int64
#  │   ├── coverage_mq0 (53200684,) int64
#  │   ├── filter_dust (53200684,) bool
#  │   ├── filter_high_coverage (53200684,) bool
#  │   ├── filter_high_mq0 (53200684,) bool
#  │   ├── filter_low_coverage (53200684,) bool
#  │   ├── filter_low_mq (53200684,) bool
#  │   ├── filter_n (53200684,) bool
#  │   ├── filter_no_coverage (53200684,) bool
#  │   ├── high_coverage (53200684,) int32
#  │   ├── high_mq0 (53200684,) int32
#  │   ├── is_accessible (53200684,) bool
#  │   ├── low_coverage (53200684,) int32
#  │   ├── low_mq (53200684,) int32
#  │   ├── low_pairing (53200684,) int32
#  │   ├── no_coverage (53200684,) int32
#  │   ├── pos (53200684,) int64
#  │   ├── ref (53200684,) |S1
#  │   ├── ref_masked (53200684,) bool
#  │   ├── ref_n (53200684,) bool
#  │   ├── repeat_dust (53200684,) bool
#  │   ├── repeat_repeatmask (53200684,) bool
#  │   └── repeat_trf (53200684,) bool
#  ├── UNKN
#  │   ├── coverage (42389979,) int64
#  │   ├── coverage_mq0 (42389979,) int64
#  │   ├── filter_dust (42389979,) bool
#  │   ├── filter_high_coverage (42389979,) bool
#  │   ├── filter_high_mq0 (42389979,) bool
#  │   ├── filter_low_coverage (42389979,) bool
#  │   ├── filter_low_mq (42389979,) bool
#  │   ├── filter_n (42389979,) bool
#  │   ├── filter_no_coverage (42389979,) bool
#  │   ├── high_coverage (42389979,) int32
#  │   ├── high_mq0 (42389979,) int32
#  │   ├── is_accessible (42389979,) bool
#  │   ├── low_coverage (42389979,) int32
#  │   ├── low_mq (42389979,) int32
#  │   ├── low_pairing (42389979,) int32
#  │   ├── no_coverage (42389979,) int32
#  │   ├── pos (42389979,) int64
#  │   ├── ref (42389979,) |S1
#  │   ├── ref_masked (42389979,) bool
#  │   ├── ref_n (42389979,) bool
#  │   ├── repeat_dust (42389979,) bool
#  │   ├── repeat_repeatmask (42389979,) bool
#  │   └── repeat_trf (42389979,) bool
#  ├── X
#  │   ├── coverage (24393108,) int64
#  │   ├── coverage_mq0 (24393108,) int64
#  │   ├── filter_dust (24393108,) bool
#  │   ├── filter_high_coverage (24393108,) bool
#  │   ├── filter_high_mq0 (24393108,) bool
#  │   ├── filter_low_coverage (24393108,) bool
#  │   ├── filter_low_mq (24393108,) bool
#  │   ├── filter_n (24393108,) bool
#  │   ├── filter_no_coverage (24393108,) bool
#  │   ├── high_coverage (24393108,) int32
#  │   ├── high_mq0 (24393108,) int32
#  │   ├── is_accessible (24393108,) bool
#  │   ├── low_coverage (24393108,) int32
#  │   ├── low_mq (24393108,) int32
#  │   ├── low_pairing (24393108,) int32
#  │   ├── no_coverage (24393108,) int32
#  │   ├── pos (24393108,) int64
#  │   ├── ref (24393108,) |S1
#  │   ├── ref_masked (24393108,) bool
#  │   ├── ref_n (24393108,) bool
#  │   ├── repeat_dust (24393108,) bool
#  │   ├── repeat_repeatmask (24393108,) bool
#  │   └── repeat_trf (24393108,) bool
#  └── Y_unplaced
#      ├── coverage (237045,) int64
#      ├── coverage_mq0 (237045,) int64
#      ├── filter_dust (237045,) bool
#      ├── filter_high_coverage (237045,) bool
#      ├── filter_high_mq0 (237045,) bool
#      ├── filter_low_coverage (237045,) bool
#      ├── filter_low_mq (237045,) bool
#      ├── filter_n (237045,) bool
#      ├── filter_no_coverage (237045,) bool
#      ├── high_coverage (237045,) int32
#      ├── high_mq0 (237045,) int32
#      ├── is_accessible (237045,) bool
#      ├── low_coverage (237045,) int32
#      ├── low_mq (237045,) int32
#      ├── low_pairing (237045,) int32
#      ├── no_coverage (237045,) int32
#      ├── pos (237045,) int64
#      ├── ref (237045,) |S1
#      ├── ref_masked (237045,) bool
#      ├── ref_n (237045,) bool
#      ├── repeat_dust (237045,) bool
#      ├── repeat_repeatmask (237045,) bool
#      └── repeat_trf (237045,) bool

# %%
import numcodecs
import sys

# %%
compressor = numcodecs.Blosc(cname='zstd', clevel=5, shuffle=-1)
zarr.copy_all(source, dest, dry_run=False, if_exists='replace', compressor=compressor, chunks=10_000_000, log=sys.stdout)
# Out:
# copy /2L
# copy /2L/coverage (49364325,) int64
# copy /2L/coverage_mq0 (49364325,) int64
# copy /2L/filter_dust (49364325,) bool
# copy /2L/filter_high_coverage (49364325,) bool
# copy /2L/filter_high_mq0 (49364325,) bool
# copy /2L/filter_low_coverage (49364325,) bool
# copy /2L/filter_low_mq (49364325,) bool
# copy /2L/filter_n (49364325,) bool
# copy /2L/filter_no_coverage (49364325,) bool
# copy /2L/high_coverage (49364325,) int32
# copy /2L/high_mq0 (49364325,) int32
# copy /2L/is_accessible (49364325,) bool
# copy /2L/low_coverage (49364325,) int32
# copy /2L/low_mq (49364325,) int32
# copy /2L/low_pairing (49364325,) int32
# copy /2L/no_coverage (49364325,) int32
# copy /2L/pos (49364325,) int64
# copy /2L/ref (49364325,) |S1
# copy /2L/ref_masked (49364325,) bool
# copy /2L/ref_n (49364325,) bool
# copy /2L/repeat_dust (49364325,) bool
# copy /2L/repeat_repeatmask (49364325,) bool
# copy /2L/repeat_trf (49364325,) bool
# copy /2R
# copy /2R/coverage (61545105,) int64
# copy /2R/coverage_mq0 (61545105,) int64
# copy /2R/filter_dust (61545105,) bool
# copy /2R/filter_high_coverage (61545105,) bool
# copy /2R/filter_high_mq0 (61545105,) bool
# copy /2R/filter_low_coverage (61545105,) bool
# copy /2R/filter_low_mq (61545105,) bool
# copy /2R/filter_n (61545105,) bool
# copy /2R/filter_no_coverage (61545105,) bool
# copy /2R/high_coverage (61545105,) int32
# copy /2R/high_mq0 (61545105,) int32
# copy /2R/is_accessible (61545105,) bool
# copy /2R/low_coverage (61545105,) int32
# copy /2R/low_mq (61545105,) int32
# copy /2R/low_pairing (61545105,) int32
# copy /2R/no_coverage (61545105,) int32
# copy /2R/pos (61545105,) int64
# copy /2R/ref (61545105,) |S1
# copy /2R/ref_masked (61545105,) bool
# copy /2R/ref_n (61545105,) bool
# copy /2R/repeat_dust (61545105,) bool
# copy /2R/repeat_repeatmask (61545105,) bool
# copy /2R/repeat_trf (61545105,) bool
# copy /3L
# copy /3L/coverage (41963435,) int64
# copy /3L/coverage_mq0 (41963435,) int64
# copy /3L/filter_dust (41963435,) bool
# copy /3L/filter_high_coverage (41963435,) bool
# copy /3L/filter_high_mq0 (41963435,) bool
# copy /3L/filter_low_coverage (41963435,) bool
# copy /3L/filter_low_mq (41963435,) bool
# copy /3L/filter_n (41963435,) bool
# copy /3L/filter_no_coverage (41963435,) bool
# copy /3L/high_coverage (41963435,) int32
# copy /3L/high_mq0 (41963435,) int32
# copy /3L/is_accessible (41963435,) bool
# copy /3L/low_coverage (41963435,) int32
# copy /3L/low_mq (41963435,) int32
# copy /3L/low_pairing (41963435,) int32
# copy /3L/no_coverage (41963435,) int32
# copy /3L/pos (41963435,) int64
# copy /3L/ref (41963435,) |S1
# copy /3L/ref_masked (41963435,) bool
# copy /3L/ref_n (41963435,) bool
# copy /3L/repeat_dust (41963435,) bool
# copy /3L/repeat_repeatmask (41963435,) bool
# copy /3L/repeat_trf (41963435,) bool
# copy /3R
# copy /3R/coverage (53200684,) int64
# copy /3R/coverage_mq0 (53200684,) int64
# copy /3R/filter_dust (53200684,) bool
# copy /3R/filter_high_coverage (53200684,) bool
# copy /3R/filter_high_mq0 (53200684,) bool
# copy /3R/filter_low_coverage (53200684,) bool
# copy /3R/filter_low_mq (53200684,) bool
# copy /3R/filter_n (53200684,) bool
# copy /3R/filter_no_coverage (53200684,) bool
# copy /3R/high_coverage (53200684,) int32
# copy /3R/high_mq0 (53200684,) int32
# copy /3R/is_accessible (53200684,) bool
# copy /3R/low_coverage (53200684,) int32
# copy /3R/low_mq (53200684,) int32
# copy /3R/low_pairing (53200684,) int32
# copy /3R/no_coverage (53200684,) int32
# copy /3R/pos (53200684,) int64
# copy /3R/ref (53200684,) |S1
# copy /3R/ref_masked (53200684,) bool
# copy /3R/ref_n (53200684,) bool
# copy /3R/repeat_dust (53200684,) bool
# copy /3R/repeat_repeatmask (53200684,) bool
# copy /3R/repeat_trf (53200684,) bool
# copy /UNKN
# copy /UNKN/coverage (42389979,) int64
# copy /UNKN/coverage_mq0 (42389979,) int64
# copy /UNKN/filter_dust (42389979,) bool
# copy /UNKN/filter_high_coverage (42389979,) bool
# copy /UNKN/filter_high_mq0 (42389979,) bool
# copy /UNKN/filter_low_coverage (42389979,) bool
# copy /UNKN/filter_low_mq (42389979,) bool
# copy /UNKN/filter_n (42389979,) bool
# copy /UNKN/filter_no_coverage (42389979,) bool
# copy /UNKN/high_coverage (42389979,) int32
# copy /UNKN/high_mq0 (42389979,) int32
# copy /UNKN/is_accessible (42389979,) bool
# copy /UNKN/low_coverage (42389979,) int32
# copy /UNKN/low_mq (42389979,) int32
# copy /UNKN/low_pairing (42389979,) int32
# copy /UNKN/no_coverage (42389979,) int32
# copy /UNKN/pos (42389979,) int64
# copy /UNKN/ref (42389979,) |S1
# copy /UNKN/ref_masked (42389979,) bool
# copy /UNKN/ref_n (42389979,) bool
# copy /UNKN/repeat_dust (42389979,) bool
# copy /UNKN/repeat_repeatmask (42389979,) bool
# copy /UNKN/repeat_trf (42389979,) bool
# copy /X
# copy /X/coverage (24393108,) int64
# copy /X/coverage_mq0 (24393108,) int64
# copy /X/filter_dust (24393108,) bool
# copy /X/filter_high_coverage (24393108,) bool
# copy /X/filter_high_mq0 (24393108,) bool
# copy /X/filter_low_coverage (24393108,) bool
# copy /X/filter_low_mq (24393108,) bool
# copy /X/filter_n (24393108,) bool
# copy /X/filter_no_coverage (24393108,) bool
# copy /X/high_coverage (24393108,) int32
# copy /X/high_mq0 (24393108,) int32
# copy /X/is_accessible (24393108,) bool
# copy /X/low_coverage (24393108,) int32
# copy /X/low_mq (24393108,) int32
# copy /X/low_pairing (24393108,) int32
# copy /X/no_coverage (24393108,) int32
# copy /X/pos (24393108,) int64
# copy /X/ref (24393108,) |S1
# copy /X/ref_masked (24393108,) bool
# copy /X/ref_n (24393108,) bool
# copy /X/repeat_dust (24393108,) bool
# copy /X/repeat_repeatmask (24393108,) bool
# copy /X/repeat_trf (24393108,) bool
# copy /Y_unplaced
# copy /Y_unplaced/coverage (237045,) int64
# copy /Y_unplaced/coverage_mq0 (237045,) int64
# copy /Y_unplaced/filter_dust (237045,) bool
# copy /Y_unplaced/filter_high_coverage (237045,) bool
# copy /Y_unplaced/filter_high_mq0 (237045,) bool
# copy /Y_unplaced/filter_low_coverage (237045,) bool
# copy /Y_unplaced/filter_low_mq (237045,) bool
# copy /Y_unplaced/filter_n (237045,) bool
# copy /Y_unplaced/filter_no_coverage (237045,) bool
# copy /Y_unplaced/high_coverage (237045,) int32
# copy /Y_unplaced/high_mq0 (237045,) int32
# copy /Y_unplaced/is_accessible (237045,) bool
# copy /Y_unplaced/low_coverage (237045,) int32
# copy /Y_unplaced/low_mq (237045,) int32
# copy /Y_unplaced/low_pairing (237045,) int32
# copy /Y_unplaced/no_coverage (237045,) int32
# copy /Y_unplaced/pos (237045,) int64
# copy /Y_unplaced/ref (237045,) |S1
# copy /Y_unplaced/ref_masked (237045,) bool
# copy /Y_unplaced/ref_n (237045,) bool
# copy /Y_unplaced/repeat_dust (237045,) bool
# copy /Y_unplaced/repeat_repeatmask (237045,) bool
# copy /Y_unplaced/repeat_trf (237045,) bool
# all done: 168 copied, 0 skipped, 16,931,808,222 bytes copied
# (168, 0, 16931808222)

# %%
# !du -hs ../data/external/*
# Out:
# 1.8G	../data/external/accessibility.h5
# 970M	../data/external/accessibility.zarr

# %%
# !ls -lh ../data/external/accessibility.zarr/2L/is_accessible/
# Out:
# total 440K
# -rw-r--r-- 1 aliman aliman 75K Nov 19 21:42 0
# -rw-r--r-- 1 aliman aliman 78K Nov 19 21:42 1
# -rw-r--r-- 1 aliman aliman 97K Nov 19 21:42 2
# -rw-r--r-- 1 aliman aliman 94K Nov 19 21:42 3
# -rw-r--r-- 1 aliman aliman 88K Nov 19 21:42 4

# %%
zarr.consolidate_metadata('../data/external/accessibility.zarr')

path = 'accessibility.zarr/'
# !gsutil -m rsync -ru ../data/external/{path} gs://ag1000g-release/phase1.AR3/accessibility/{path}

# %%
# check via intake catalog

# %%
import intake

# %%
cat = intake.open_catalog('https://malariagen.github.io/intake/gcs.yml')
cat
# Out:
# gcs:
#   args:
#     path: https://malariagen.github.io/intake/gcs.yml
#   description: ''
#   driver: intake.catalog.local.YAMLFileCatalog
#   metadata:
#     version: 1

# %%
list(cat.ag1)
# Out:
# ['samples',
#  'snps',
#  'snps_pass',
#  'snps_pass_biallelic',
#  'haps',
#  'accessibility']

# %%
accessibility = cat.ag1.accessibility.to_zarr()
accessibility
# Out:
# <zarr.hierarchy.Group '/' read-only>

# %%
print(accessibility.tree())
# Out:
# /
#  ├── 2L
#  │   ├── coverage (49364325,) int64
#  │   ├── coverage_mq0 (49364325,) int64
#  │   ├── filter_dust (49364325,) bool
#  │   ├── filter_high_coverage (49364325,) bool
#  │   ├── filter_high_mq0 (49364325,) bool
#  │   ├── filter_low_coverage (49364325,) bool
#  │   ├── filter_low_mq (49364325,) bool
#  │   ├── filter_n (49364325,) bool
#  │   ├── filter_no_coverage (49364325,) bool
#  │   ├── high_coverage (49364325,) int32
#  │   ├── high_mq0 (49364325,) int32
#  │   ├── is_accessible (49364325,) bool
#  │   ├── low_coverage (49364325,) int32
#  │   ├── low_mq (49364325,) int32
#  │   ├── low_pairing (49364325,) int32
#  │   ├── no_coverage (49364325,) int32
#  │   ├── pos (49364325,) int64
#  │   ├── ref (49364325,) |S1
#  │   ├── ref_masked (49364325,) bool
#  │   ├── ref_n (49364325,) bool
#  │   ├── repeat_dust (49364325,) bool
#  │   ├── repeat_repeatmask (49364325,) bool
#  │   └── repeat_trf (49364325,) bool
#  ├── 2R
#  │   ├── coverage (61545105,) int64
#  │   ├── coverage_mq0 (61545105,) int64
#  │   ├── filter_dust (61545105,) bool
#  │   ├── filter_high_coverage (61545105,) bool
#  │   ├── filter_high_mq0 (61545105,) bool
#  │   ├── filter_low_coverage (61545105,) bool
#  │   ├── filter_low_mq (61545105,) bool
#  │   ├── filter_n (61545105,) bool
#  │   ├── filter_no_coverage (61545105,) bool
#  │   ├── high_coverage (61545105,) int32
#  │   ├── high_mq0 (61545105,) int32
#  │   ├── is_accessible (61545105,) bool
#  │   ├── low_coverage (61545105,) int32
#  │   ├── low_mq (61545105,) int32
#  │   ├── low_pairing (61545105,) int32
#  │   ├── no_coverage (61545105,) int32
#  │   ├── pos (61545105,) int64
#  │   ├── ref (61545105,) |S1
#  │   ├── ref_masked (61545105,) bool
#  │   ├── ref_n (61545105,) bool
#  │   ├── repeat_dust (61545105,) bool
#  │   ├── repeat_repeatmask (61545105,) bool
#  │   └── repeat_trf (61545105,) bool
#  ├── 3L
#  │   ├── coverage (41963435,) int64
#  │   ├── coverage_mq0 (41963435,) int64
#  │   ├── filter_dust (41963435,) bool
#  │   ├── filter_high_coverage (41963435,) bool
#  │   ├── filter_high_mq0 (41963435,) bool
#  │   ├── filter_low_coverage (41963435,) bool
#  │   ├── filter_low_mq (41963435,) bool
#  │   ├── filter_n (41963435,) bool
#  │   ├── filter_no_coverage (41963435,) bool
#  │   ├── high_coverage (41963435,) int32
#  │   ├── high_mq0 (41963435,) int32
#  │   ├── is_accessible (41963435,) bool
#  │   ├── low_coverage (41963435,) int32
#  │   ├── low_mq (41963435,) int32
#  │   ├── low_pairing (41963435,) int32
#  │   ├── no_coverage (41963435,) int32
#  │   ├── pos (41963435,) int64
#  │   ├── ref (41963435,) |S1
#  │   ├── ref_masked (41963435,) bool
#  │   ├── ref_n (41963435,) bool
#  │   ├── repeat_dust (41963435,) bool
#  │   ├── repeat_repeatmask (41963435,) bool
#  │   └── repeat_trf (41963435,) bool
#  ├── 3R
#  │   ├── coverage (53200684,) int64
#  │   ├── coverage_mq0 (53200684,) int64
#  │   ├── filter_dust (53200684,) bool
#  │   ├── filter_high_coverage (53200684,) bool
#  │   ├── filter_high_mq0 (53200684,) bool
#  │   ├── filter_low_coverage (53200684,) bool
#  │   ├── filter_low_mq (53200684,) bool
#  │   ├── filter_n (53200684,) bool
#  │   ├── filter_no_coverage (53200684,) bool
#  │   ├── high_coverage (53200684,) int32
#  │   ├── high_mq0 (53200684,) int32
#  │   ├── is_accessible (53200684,) bool
#  │   ├── low_coverage (53200684,) int32
#  │   ├── low_mq (53200684,) int32
#  │   ├── low_pairing (53200684,) int32
#  │   ├── no_coverage (53200684,) int32
#  │   ├── pos (53200684,) int64
#  │   ├── ref (53200684,) |S1
#  │   ├── ref_masked (53200684,) bool
#  │   ├── ref_n (53200684,) bool
#  │   ├── repeat_dust (53200684,) bool
#  │   ├── repeat_repeatmask (53200684,) bool
#  │   └── repeat_trf (53200684,) bool
#  ├── UNKN
#  │   ├── coverage (42389979,) int64
#  │   ├── coverage_mq0 (42389979,) int64
#  │   ├── filter_dust (42389979,) bool
#  │   ├── filter_high_coverage (42389979,) bool
#  │   ├── filter_high_mq0 (42389979,) bool
#  │   ├── filter_low_coverage (42389979,) bool
#  │   ├── filter_low_mq (42389979,) bool
#  │   ├── filter_n (42389979,) bool
#  │   ├── filter_no_coverage (42389979,) bool
#  │   ├── high_coverage (42389979,) int32
#  │   ├── high_mq0 (42389979,) int32
#  │   ├── is_accessible (42389979,) bool
#  │   ├── low_coverage (42389979,) int32
#  │   ├── low_mq (42389979,) int32
#  │   ├── low_pairing (42389979,) int32
#  │   ├── no_coverage (42389979,) int32
#  │   ├── pos (42389979,) int64
#  │   ├── ref (42389979,) |S1
#  │   ├── ref_masked (42389979,) bool
#  │   ├── ref_n (42389979,) bool
#  │   ├── repeat_dust (42389979,) bool
#  │   ├── repeat_repeatmask (42389979,) bool
#  │   └── repeat_trf (42389979,) bool
#  ├── X
#  │   ├── coverage (24393108,) int64
#  │   ├── coverage_mq0 (24393108,) int64
#  │   ├── filter_dust (24393108,) bool
#  │   ├── filter_high_coverage (24393108,) bool
#  │   ├── filter_high_mq0 (24393108,) bool
#  │   ├── filter_low_coverage (24393108,) bool
#  │   ├── filter_low_mq (24393108,) bool
#  │   ├── filter_n (24393108,) bool
#  │   ├── filter_no_coverage (24393108,) bool
#  │   ├── high_coverage (24393108,) int32
#  │   ├── high_mq0 (24393108,) int32
#  │   ├── is_accessible (24393108,) bool
#  │   ├── low_coverage (24393108,) int32
#  │   ├── low_mq (24393108,) int32
#  │   ├── low_pairing (24393108,) int32
#  │   ├── no_coverage (24393108,) int32
#  │   ├── pos (24393108,) int64
#  │   ├── ref (24393108,) |S1
#  │   ├── ref_masked (24393108,) bool
#  │   ├── ref_n (24393108,) bool
#  │   ├── repeat_dust (24393108,) bool
#  │   ├── repeat_repeatmask (24393108,) bool
#  │   └── repeat_trf (24393108,) bool
#  └── Y_unplaced
#      ├── coverage (237045,) int64
#      ├── coverage_mq0 (237045,) int64
#      ├── filter_dust (237045,) bool
#      ├── filter_high_coverage (237045,) bool
#      ├── filter_high_mq0 (237045,) bool
#      ├── filter_low_coverage (237045,) bool
#      ├── filter_low_mq (237045,) bool
#      ├── filter_n (237045,) bool
#      ├── filter_no_coverage (237045,) bool
#      ├── high_coverage (237045,) int32
#      ├── high_mq0 (237045,) int32
#      ├── is_accessible (237045,) bool
#      ├── low_coverage (237045,) int32
#      ├── low_mq (237045,) int32
#      ├── low_pairing (237045,) int32
#      ├── no_coverage (237045,) int32
#      ├── pos (237045,) int64
#      ├── ref (237045,) |S1
#      ├── ref_masked (237045,) bool
#      ├── ref_n (237045,) bool
#      ├── repeat_dust (237045,) bool
#      ├── repeat_repeatmask (237045,) bool
#      └── repeat_trf (237045,) bool

# %%
accessibility['3R/is_accessible'][:]
# Out:
# array([False, False, False, ..., False, False, False])

# %%
accessibility['3R/is_accessible'].nchunks_initialized
# Out:
# 6

# %%
for chrom in accessibility:
    for d in accessibility[chrom]:
        print(chrom, d)
        a = accessibility[chrom][d]
        assert a.nchunks == a.nchunks_initialized
# Out:
# 2L coverage
# 2L coverage_mq0
# 2L filter_dust
# 2L filter_high_coverage
# 2L filter_high_mq0
# 2L filter_low_coverage
# 2L filter_low_mq
# 2L filter_n
# 2L filter_no_coverage
# 2L high_coverage
# 2L high_mq0
# 2L is_accessible
# 2L low_coverage
# 2L low_mq
# 2L low_pairing
# 2L no_coverage
# 2L pos
# 2L ref
# 2L ref_masked
# 2L ref_n
# 2L repeat_dust
# 2L repeat_repeatmask
# 2L repeat_trf
# 2R coverage
# 2R coverage_mq0
# 2R filter_dust
# 2R filter_high_coverage
# 2R filter_high_mq0
# 2R filter_low_coverage
# 2R filter_low_mq
# 2R filter_n
# 2R filter_no_coverage
# 2R high_coverage
# 2R high_mq0
# 2R is_accessible
# 2R low_coverage
# 2R low_mq
# 2R low_pairing
# 2R no_coverage
# 2R pos
# 2R ref
# 2R ref_masked
# 2R ref_n
# 2R repeat_dust
# 2R repeat_repeatmask
# 2R repeat_trf
# 3L coverage
# 3L coverage_mq0
# 3L filter_dust
# 3L filter_high_coverage
# 3L filter_high_mq0
# 3L filter_low_coverage
# 3L filter_low_mq
# 3L filter_n
# 3L filter_no_coverage
# 3L high_coverage
# 3L high_mq0
# 3L is_accessible
# 3L low_coverage
# 3L low_mq
# 3L low_pairing
# 3L no_coverage
# 3L pos
# 3L ref
# 3L ref_masked
# 3L ref_n
# 3L repeat_dust
# 3L repeat_repeatmask
# 3L repeat_trf
# 3R coverage
# 3R coverage_mq0
# 3R filter_dust
# 3R filter_high_coverage
# 3R filter_high_mq0
# 3R filter_low_coverage
# 3R filter_low_mq
# 3R filter_n
# 3R filter_no_coverage
# 3R high_coverage
# 3R high_mq0
# 3R is_accessible
# 3R low_coverage
# 3R low_mq
# 3R low_pairing
# 3R no_coverage
# 3R pos
# 3R ref
# 3R ref_masked
# 3R ref_n
# 3R repeat_dust
# 3R repeat_repeatmask
# 3R repeat_trf
# UNKN coverage
# UNKN coverage_mq0
# UNKN filter_dust
# UNKN filter_high_coverage
# UNKN filter_high_mq0
# UNKN filter_low_coverage
# UNKN filter_low_mq
# UNKN filter_n
# UNKN filter_no_coverage
# UNKN high_coverage
# UNKN high_mq0
# UNKN is_accessible
# UNKN low_coverage
# UNKN low_mq
# UNKN low_pairing
# UNKN no_coverage
# UNKN pos
# UNKN ref
# UNKN ref_masked
# UNKN ref_n
# UNKN repeat_dust
# UNKN repeat_repeatmask
# UNKN repeat_trf
# X coverage
# X coverage_mq0
# X filter_dust
# X filter_high_coverage
# X filter_high_mq0
# X filter_low_coverage
# X filter_low_mq
# X filter_n
# X filter_no_coverage
# X high_coverage
# X high_mq0
# X is_accessible
# X low_coverage
# X low_mq
# X low_pairing
# X no_coverage
# X pos
# X ref
# X ref_masked
# X ref_n
# X repeat_dust
# X repeat_repeatmask
# X repeat_trf
# Y_unplaced coverage
# Y_unplaced coverage_mq0
# Y_unplaced filter_dust
# Y_unplaced filter_high_coverage
# Y_unplaced filter_high_mq0
# Y_unplaced filter_low_coverage
# Y_unplaced filter_low_mq
# Y_unplaced filter_n
# Y_unplaced filter_no_coverage
# Y_unplaced high_coverage
# Y_unplaced high_mq0
# Y_unplaced is_accessible
# Y_unplaced low_coverage
# Y_unplaced low_mq
# Y_unplaced low_pairing
# Y_unplaced no_coverage
# Y_unplaced pos
# Y_unplaced ref
# Y_unplaced ref_masked
# Y_unplaced ref_n
# Y_unplaced repeat_dust
# Y_unplaced repeat_repeatmask
# Y_unplaced repeat_trf

# %%
# !wget --no-clobber https://storage.googleapis.com/ag1000g-release/phase1.AR3/extras/allele_counts.h5 -O ../data/external/allele_counts.h5
# Out:
# File ‘../data/external/allele_counts.h5’ already there; not retrieving.

# %%
import zarr

dest = zarr.open('../data/external/allele_counts.zarr', mode='w')

import h5py

source = h5py.File('../data/external/allele_counts.h5', mode='r')

# %%
print(zarr.tree(source))
# Out:
# /
#  ├── 2L
#  │   ├── AOM (10377280, 4) int32
#  │   ├── BFM (10377280, 4) int32
#  │   ├── BFS (10377280, 4) int32
#  │   ├── CMS (10377280, 4) int32
#  │   ├── GAS (10377280, 4) int32
#  │   ├── GNS (10377280, 4) int32
#  │   ├── GWA (10377280, 4) int32
#  │   ├── KES (10377280, 4) int32
#  │   ├── UGS (10377280, 4) int32
#  │   ├── all (10377280, 4) int32
#  │   ├── all_m (10377280, 4) int32
#  │   └── all_s (10377280, 4) int32
#  ├── 2R
#  │   ├── AOM (14080970, 4) int32
#  │   ├── BFM (14080970, 4) int32
#  │   ├── BFS (14080970, 4) int32
#  │   ├── CMS (14080970, 4) int32
#  │   ├── GAS (14080970, 4) int32
#  │   ├── GNS (14080970, 4) int32
#  │   ├── GWA (14080970, 4) int32
#  │   ├── KES (14080970, 4) int32
#  │   ├── UGS (14080970, 4) int32
#  │   ├── all (14080970, 4) int32
#  │   ├── all_m (14080970, 4) int32
#  │   └── all_s (14080970, 4) int32
#  ├── 3L
#  │   ├── AOM (9643193, 4) int32
#  │   ├── BFM (9643193, 4) int32
#  │   ├── BFS (9643193, 4) int32
#  │   ├── CMS (9643193, 4) int32
#  │   ├── GAS (9643193, 4) int32
#  │   ├── GNS (9643193, 4) int32
#  │   ├── GWA (9643193, 4) int32
#  │   ├── KES (9643193, 4) int32
#  │   ├── UGS (9643193, 4) int32
#  │   ├── all (9643193, 4) int32
#  │   ├── all_m (9643193, 4) int32
#  │   └── all_s (9643193, 4) int32
#  ├── 3R
#  │   ├── AOM (13167162, 4) int32
#  │   ├── BFM (13167162, 4) int32
#  │   ├── BFS (13167162, 4) int32
#  │   ├── CMS (13167162, 4) int32
#  │   ├── GAS (13167162, 4) int32
#  │   ├── GNS (13167162, 4) int32
#  │   ├── GWA (13167162, 4) int32
#  │   ├── KES (13167162, 4) int32
#  │   ├── UGS (13167162, 4) int32
#  │   ├── all (13167162, 4) int32
#  │   ├── all_m (13167162, 4) int32
#  │   └── all_s (13167162, 4) int32
#  └── X
#      ├── AOM (5257352, 4) int32
#      ├── BFM (5257352, 4) int32
#      ├── BFS (5257352, 4) int32
#      ├── CMS (5257352, 4) int32
#      ├── GAS (5257352, 4) int32
#      ├── GNS (5257352, 4) int32
#      ├── GWA (5257352, 4) int32
#      ├── KES (5257352, 4) int32
#      ├── UGS (5257352, 4) int32
#      ├── all (5257352, 4) int32
#      ├── all_m (5257352, 4) int32
#      └── all_s (5257352, 4) int32

# %%
compressor = numcodecs.Blosc(cname='zstd', clevel=5, shuffle=-1)
zarr.copy_all(source, dest, dry_run=False, if_exists='replace', compressor=compressor, chunks=(10_000_000, -1), log=sys.stdout)
# Out:
# copy /2L
# copy /2L/AOM (10377280, 4) int32
# copy /2L/BFM (10377280, 4) int32
# copy /2L/BFS (10377280, 4) int32
# copy /2L/CMS (10377280, 4) int32
# copy /2L/GAS (10377280, 4) int32
# copy /2L/GNS (10377280, 4) int32
# copy /2L/GWA (10377280, 4) int32
# copy /2L/KES (10377280, 4) int32
# copy /2L/UGS (10377280, 4) int32
# copy /2L/all (10377280, 4) int32
# copy /2L/all_m (10377280, 4) int32
# copy /2L/all_s (10377280, 4) int32
# copy /2R
# copy /2R/AOM (14080970, 4) int32
# copy /2R/BFM (14080970, 4) int32
# copy /2R/BFS (14080970, 4) int32
# copy /2R/CMS (14080970, 4) int32
# copy /2R/GAS (14080970, 4) int32
# copy /2R/GNS (14080970, 4) int32
# copy /2R/GWA (14080970, 4) int32
# copy /2R/KES (14080970, 4) int32
# copy /2R/UGS (14080970, 4) int32
# copy /2R/all (14080970, 4) int32
# copy /2R/all_m (14080970, 4) int32
# copy /2R/all_s (14080970, 4) int32
# copy /3L
# copy /3L/AOM (9643193, 4) int32
# copy /3L/BFM (9643193, 4) int32
# copy /3L/BFS (9643193, 4) int32
# copy /3L/CMS (9643193, 4) int32
# copy /3L/GAS (9643193, 4) int32
# copy /3L/GNS (9643193, 4) int32
# copy /3L/GWA (9643193, 4) int32
# copy /3L/KES (9643193, 4) int32
# copy /3L/UGS (9643193, 4) int32
# copy /3L/all (9643193, 4) int32
# copy /3L/all_m (9643193, 4) int32
# copy /3L/all_s (9643193, 4) int32
# copy /3R
# copy /3R/AOM (13167162, 4) int32
# copy /3R/BFM (13167162, 4) int32
# copy /3R/BFS (13167162, 4) int32
# copy /3R/CMS (13167162, 4) int32
# copy /3R/GAS (13167162, 4) int32
# copy /3R/GNS (13167162, 4) int32
# copy /3R/GWA (13167162, 4) int32
# copy /3R/KES (13167162, 4) int32
# copy /3R/UGS (13167162, 4) int32
# copy /3R/all (13167162, 4) int32
# copy /3R/all_m (13167162, 4) int32
# copy /3R/all_s (13167162, 4) int32
# copy /X
# copy /X/AOM (5257352, 4) int32
# copy /X/BFM (5257352, 4) int32
# copy /X/BFS (5257352, 4) int32
# copy /X/CMS (5257352, 4) int32
# copy /X/GAS (5257352, 4) int32
# copy /X/GNS (5257352, 4) int32
# copy /X/GWA (5257352, 4) int32
# copy /X/KES (5257352, 4) int32
# copy /X/UGS (5257352, 4) int32
# copy /X/all (5257352, 4) int32
# copy /X/all_m (5257352, 4) int32
# copy /X/all_s (5257352, 4) int32
# all done: 65 copied, 0 skipped, 10,084,983,744 bytes copied
# (65, 0, 10084983744)

# %%
zarr.consolidate_metadata('../data/external/allele_counts.zarr')

path = 'allele_counts.zarr/'
# !gsutil -m rsync -ru ../data/external/{path} gs://ag1000g-release/phase1.AR3/extras/{path}
# Out:
# Building synchronization state...
# Starting synchronization...
# Copying file://../data/external/allele_counts.zarr/.zgroup [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/.zmetadata [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2L/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2L/.zgroup [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2L/AOM/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2L/AOM/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2L/BFM/1.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2L/BFM/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2L/BFM/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2L/BFS/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2L/BFS/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2L/BFS/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2L/AOM/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2L/AOM/1.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2L/KES/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2L/CMS/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2L/BFM/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2L/CMS/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2L/CMS/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2L/GAS/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2L/GNS/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2L/GAS/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2L/GAS/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2L/CMS/1.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2L/GAS/1.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2L/GWA/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2L/GWA/1.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2L/GNS/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2L/KES/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2L/GWA/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2L/GNS/1.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2L/GWA/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2L/KES/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2L/BFS/1.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2L/KES/1.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2L/GNS/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2L/UGS/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2L/all/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2L/UGS/1.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2L/all/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2L/all_m/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2L/all_m/1.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2L/UGS/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2L/all_s/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2L/all_m/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2L/all/1.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2L/all_m/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2L/all/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2L/all_s/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2L/UGS/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2L/all_s/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2L/all_s/1.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2R/AOM/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2R/AOM/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2R/AOM/1.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2R/AOM/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2R/BFM/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2R/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2R/BFM/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2R/BFM/1.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2R/BFS/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2R/BFS/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2R/CMS/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2R/BFM/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2R/.zgroup [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2R/BFS/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2R/BFS/1.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2R/GAS/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2R/CMS/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2R/GAS/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2R/GAS/1.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2R/CMS/1.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2R/GNS/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2R/GNS/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2R/GNS/1.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2R/GAS/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2R/GNS/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2R/CMS/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2R/GWA/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2R/GWA/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2R/GWA/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2R/GWA/1.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2R/KES/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2R/KES/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2R/KES/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2R/KES/1.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2R/UGS/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2R/UGS/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2R/all/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2R/all/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2R/all/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2R/UGS/1.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2R/all/1.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2R/all_m/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2R/all_m/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2R/UGS/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2R/all_s/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2R/all_m/1.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2R/all_s/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2R/all_s/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2R/all_m/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/2R/all_s/1.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3L/AOM/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3L/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3L/.zgroup [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3L/AOM/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3L/AOM/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3L/CMS/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3L/BFM/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3L/BFM/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3L/CMS/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3L/BFS/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3L/BFS/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3L/GAS/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3L/BFS/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3L/CMS/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3L/GNS/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3L/GAS/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3L/BFM/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3L/GAS/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3L/GNS/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3L/GNS/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3L/GWA/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3L/GWA/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3L/GWA/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3L/KES/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3L/KES/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3L/KES/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3L/UGS/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3L/UGS/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3L/all/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3L/all_m/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3L/all/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3L/all/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3L/UGS/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3L/all_m/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3L/all_m/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3L/all_s/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3L/all_s/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3R/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3L/all_s/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3R/AOM/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3R/AOM/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3R/AOM/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3R/AOM/1.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3R/.zgroup [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3R/BFM/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3R/BFM/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3R/BFM/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3R/BFS/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3R/BFM/1.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3R/BFS/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3R/BFS/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3R/BFS/1.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3R/CMS/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3R/CMS/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3R/CMS/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3R/CMS/1.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3R/GAS/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3R/GAS/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3R/GAS/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3R/GAS/1.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3R/GNS/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3R/GNS/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3R/GNS/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3R/GNS/1.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3R/GWA/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3R/GWA/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3R/GWA/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3R/GWA/1.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3R/KES/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3R/KES/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3R/KES/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3R/KES/1.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3R/UGS/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3R/UGS/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3R/UGS/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3R/UGS/1.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3R/all/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3R/all/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3R/all/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3R/all/1.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3R/all_m/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3R/all_m/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3R/all_m/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3R/all_m/1.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3R/all_s/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3R/all_s/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3R/all_s/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/3R/all_s/1.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/X/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/X/.zgroup [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/X/AOM/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/X/AOM/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/X/AOM/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/X/BFM/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/X/BFM/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/X/BFM/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/X/BFS/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/X/BFS/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/X/BFS/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/X/CMS/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/X/CMS/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/X/CMS/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/X/GAS/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/X/GAS/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/X/GAS/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/X/GNS/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/X/GNS/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/X/GNS/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/X/GWA/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/X/GWA/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/X/GWA/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/X/KES/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/X/KES/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/X/KES/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/X/UGS/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/X/UGS/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/X/UGS/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/X/all/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/X/all/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/X/all/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/X/all_m/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/X/all_m/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/X/all_m/0.0 [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/X/all_s/.zarray [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/X/all_s/.zattrs [Content-Type=application/octet-stream]...
# Copying file://../data/external/allele_counts.zarr/X/all_s/0.0 [Content-Type=application/octet-stream]...
# / [228/228 files][495.3 MiB/495.3 MiB] 100% Done 989.9 KiB/s ETA 00:00:00
# Operation completed over 228 objects/495.3 MiB.

# %%
allele_counts = cat.ag1.allele_counts.to_zarr()
allele_counts
# Out:
# <zarr.hierarchy.Group '/' read-only>

# %%
print(allele_counts.tree())
# Out:
# /
#  ├── 2L
#  │   ├── AOM (10377280, 4) int32
#  │   ├── BFM (10377280, 4) int32
#  │   ├── BFS (10377280, 4) int32
#  │   ├── CMS (10377280, 4) int32
#  │   ├── GAS (10377280, 4) int32
#  │   ├── GNS (10377280, 4) int32
#  │   ├── GWA (10377280, 4) int32
#  │   ├── KES (10377280, 4) int32
#  │   ├── UGS (10377280, 4) int32
#  │   ├── all (10377280, 4) int32
#  │   ├── all_m (10377280, 4) int32
#  │   └── all_s (10377280, 4) int32
#  ├── 2R
#  │   ├── AOM (14080970, 4) int32
#  │   ├── BFM (14080970, 4) int32
#  │   ├── BFS (14080970, 4) int32
#  │   ├── CMS (14080970, 4) int32
#  │   ├── GAS (14080970, 4) int32
#  │   ├── GNS (14080970, 4) int32
#  │   ├── GWA (14080970, 4) int32
#  │   ├── KES (14080970, 4) int32
#  │   ├── UGS (14080970, 4) int32
#  │   ├── all (14080970, 4) int32
#  │   ├── all_m (14080970, 4) int32
#  │   └── all_s (14080970, 4) int32
#  ├── 3L
#  │   ├── AOM (9643193, 4) int32
#  │   ├── BFM (9643193, 4) int32
#  │   ├── BFS (9643193, 4) int32
#  │   ├── CMS (9643193, 4) int32
#  │   ├── GAS (9643193, 4) int32
#  │   ├── GNS (9643193, 4) int32
#  │   ├── GWA (9643193, 4) int32
#  │   ├── KES (9643193, 4) int32
#  │   ├── UGS (9643193, 4) int32
#  │   ├── all (9643193, 4) int32
#  │   ├── all_m (9643193, 4) int32
#  │   └── all_s (9643193, 4) int32
#  ├── 3R
#  │   ├── AOM (13167162, 4) int32
#  │   ├── BFM (13167162, 4) int32
#  │   ├── BFS (13167162, 4) int32
#  │   ├── CMS (13167162, 4) int32
#  │   ├── GAS (13167162, 4) int32
#  │   ├── GNS (13167162, 4) int32
#  │   ├── GWA (13167162, 4) int32
#  │   ├── KES (13167162, 4) int32
#  │   ├── UGS (13167162, 4) int32
#  │   ├── all (13167162, 4) int32
#  │   ├── all_m (13167162, 4) int32
#  │   └── all_s (13167162, 4) int32
#  └── X
#      ├── AOM (5257352, 4) int32
#      ├── BFM (5257352, 4) int32
#      ├── BFS (5257352, 4) int32
#      ├── CMS (5257352, 4) int32
#      ├── GAS (5257352, 4) int32
#      ├── GNS (5257352, 4) int32
#      ├── GWA (5257352, 4) int32
#      ├── KES (5257352, 4) int32
#      ├── UGS (5257352, 4) int32
#      ├── all (5257352, 4) int32
#      ├── all_m (5257352, 4) int32
#      └── all_s (5257352, 4) int32

# %%
for chrom in allele_counts:
    for d in allele_counts[chrom]:
        print(chrom, d)
        a = allele_counts[chrom][d]
        assert a.nchunks == a.nchunks_initialized
# Out:
# 2L AOM
# 2L BFM
# 2L BFS
# 2L CMS
# 2L GAS
# 2L GNS
# 2L GWA
# 2L KES
# 2L UGS
# 2L all
# 2L all_m
# 2L all_s
# 2R AOM
# 2R BFM
# 2R BFS
# 2R CMS
# 2R GAS
# 2R GNS
# 2R GWA
# 2R KES
# 2R UGS
# 2R all
# 2R all_m
# 2R all_s
# 3L AOM
# 3L BFM
# 3L BFS
# 3L CMS
# 3L GAS
# 3L GNS
# 3L GWA
# 3L KES
# 3L UGS
# 3L all
# 3L all_m
# 3L all_s
# 3R AOM
# 3R BFM
# 3R BFS
# 3R CMS
# 3R GAS
# 3R GNS
# 3R GWA
# 3R KES
# 3R UGS
# 3R all
# 3R all_m
# 3R all_s
# X AOM
# X BFM
# X BFS
# X CMS
# X GAS
# X GNS
# X GWA
# X KES
# X UGS
# X all
# X all_m
# X all_s
